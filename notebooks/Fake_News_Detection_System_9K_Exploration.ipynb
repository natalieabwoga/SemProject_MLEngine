# %%
# !pip install datasets -q
import pandas as pd
import numpy as np
from datasets import load_dataset

hf_data = load_dataset("lusamaki/Fake_News_Detection_System_9K")
dataset = hf_data['train'].to_pandas()

dataset.head()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/94.0 [00:00<?, ?B/s]
# train_dataset.csv:   0%|          | 0.00/1.64M [00:00<?, ?B/s]
# test_dataset.csv:   0%|          | 0.00/705k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/6300 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2700 [00:00<?, ? examples/s]
#    Unnamed: 0                                              tweet    label  \
# 0        5266  @user @user So he only worked from June 1st to...     fact
# 1        4574  It s 61 days to 2022 general elections to end ...     fact
# 2          96        @user Kenya Kwanza yaongezewa @user za tena  neutral
# 3        1967  There will be no need of panic\nAvoid incompet...     fact
# 4         118  IEBC Kenya imeweka mbinu mbili kuu za kuwatamb...     fact
#
#                                                 text language  contains_emoji
# 0  worked june st alter presidential elections re...    sheng            True
# 1  s days general elections end martharao sababu ...    sheng           False
# 2                    kenya kwanza yaongezewa za tena  Swahili           False
# 3  need panicavoid incompetence vote wiselykenyad...    sheng           False
# 4  iebc kenya imeweka mbinu mbili kuu za kuwatamb...  Swahili           False

# %%
rows, cols = dataset.shape

print("Rows:", rows)
print("Columns:", cols)
# Out:
# Rows: 6300
# Columns: 6

# %%
print(dataset.dtypes)
# Out:
# Unnamed: 0         int64
# tweet             object
# label             object
# text              object
# language          object
# contains_emoji      bool
# dtype: object

# %%
empty_per_col = dataset.isna().sum()
all_empty = empty_per_col.sum()

print(empty_per_col)
print("\nTotal empty cells:", all_empty)

if all_empty == 0:
    print("The dataset is complete.")
else:
    print(f"The dataset is incomplete. It is missing {all_empty} values.")
# Out:
# Unnamed: 0        0
# tweet             0
# label             0
# text              0
# language          0
# contains_emoji    0
# dtype: int64
#
# Total empty cells: 0
# The dataset is complete.

# %%
set_head = dataset.head(15)
set_tail = dataset.tail(20)

df_sample = pd.concat([set_head, set_tail])

print("Shape:", df_sample.shape)
df_sample
# Out:
# Shape: (35, 6)
#       Unnamed: 0                                              tweet    label  \
# 0           5266  @user @user So he only worked from June 1st to...     fact
# 1           4574  It s 61 days to 2022 general elections to end ...     fact
# 2             96        @user Kenya Kwanza yaongezewa @user za tena  neutral
# 3           1967  There will be no need of panic\nAvoid incompet...     fact
# 4            118  IEBC Kenya imeweka mbinu mbili kuu za kuwatamb...     fact
# 5           1521  @user Show us your tallying centre Bladfwakin ...     fact
# 6          15992  youthagenda254 Oayouthkenya UN Women ChiromoHo...  neutral
# 7             77  @user @user Tuliza familia uliyoua mwana wao k...     fake
# 8           2793  Mizani polls show TheODMparty Gubernatorial ca...  neutral
# 9            530  @user stop the theatrics and announce the winn...  neutral
# 10          3195  Leaders say no to corruption. EACCKenya IEBC K...  neutral
# 11           176          SakajaJohnson WilliamsRuto Hongera kabisa     fact
# 12           104  @user @user W@user jsckenya CJIEBC Kenya@user ...  neutral
# 13          7948  Let’s get out and VOTE 💙 President @user DP @u...  neutral
# 14            88  @user @user @user Na bado mtaongoja miaka ingi...  neutral
# 6280        8022  KenyaDecides2022\nJust voted buruu the karaa v...  neutral
# 6281         106  citize@user kenya kenya decides 2022 KenyasCho...     fact
# 6282       18995  So unfortunate that Baba has never lost any of...     fake
# 6283        1111  Assmio supporters will not vote in masses beca...     fake
# 6284         178  milkawangui12 Gvn ni susankihika senator ~ Tab...     fake
# 6285       11591  blongwe kachwanya TonwaTai You and I understan...     fake
# 6286         116  Vijana wa Naivasha wameamua kuweka amani sasa ...     fact
# 6287         116  Vijana wa Naivasha wameamua kuweka amani sasa ...     fact
# 6288        4073  Now we are getting somewhere Real substantive ...  neutral
# 6289         148  e odeo Hiyo kazi na ya IEBC hakuna difference....     fake
# 6290          99  @user Kazi n Kazi tumeanza https://t.co/jwcu4Z...     fact
# 6291        3147  Keep this and retrieve in 15 days. The best th...  neutral
# 6292          16                          @user @user Mungu n mwema  neutral
# 6293        9366  DCI Kenya @user @user kenya KTNNewsKE is this ...     fact
# 6294        3636  Over to you IEBC Kenya let s know what your up...     fake
# 6295        4922  If only Kenya had a petition website. We would...     fact
# 6296         184                  WilliamsRuto Kura umeshindua wewe     fake
# 6297        9539  mose @user m Trying to twist the statement to ...     fake
# 6298        4451  @user Karua ndio kigezo kwa kalonzo kujiunga n...     fake
# 6299         896  A rare picture of what will be hanging in all ...  neutral
#
#                                                    text language  \
# 0     worked june st alter presidential elections re...    sheng
# 1     s days general elections end martharao sababu ...    sheng
# 2                       kenya kwanza yaongezewa za tena  Swahili
# 3     need panicavoid incompetence vote wiselykenyad...    sheng
# 4     iebc kenya imeweka mbinu mbili kuu za kuwatamb...  Swahili
# 5                       tallying centre bladfwakin wewe    sheng
# 6     youthagenda254 oayouthkenya women chiromohospg...  English
# 7               tuliza familia uliyoua mwana wao kwanza  Swahili
# 8     mizani polls theodmparty gubernatorial candida...    sheng
# 9     stop theatrics announce winner able leaders ke...  English
# 10    leaders corruption eacckenya iebc kenya ncic k...    sheng
# 11            sakajajohnson williamsruto hongera kabisa  Swahili
# 12    w jsckenya cjiebc kenya kenya judiciary hautat...  Swahili
# 13    lets vote president dp governor senator women ...  English
# 14                  na bado mtaongoja miaka ingine tano  Swahili
# 6280  kenyadecides2022just voted buruu karaa voted c...  English
# 6281  citize kenya kenya decides kenyaschoice2022 sa...  Swahili
# 6282  unfortunate baba lost elections rigged s time ...  English
# 6283  assmio supporters vote masses because1 countin...    sheng
# 6284  milkawangui12 gvn ni susankihika senator tabit...  Swahili
# 6285  blongwe kachwanya tonwatai understand english ...  English
# 6286  vijana wa naivasha wameamua kuweka amani sasa ...  Swahili
# 6287  vijana wa naivasha wameamua kuweka amani sasa ...  Swahili
# 6288  getting real substantive issues praising chebu...    sheng
# 6289  e odeo hiyo kazi na ya iebc hakuna difference ...  Swahili
# 6290                               kazi n kazi tumeanza  Swahili
# 6291  retrieve days best achieve percent kura merufm...    sheng
# 6292                                      mungu n mwema  Swahili
# 6293  dci kenya kenya ktnnewske information clear fa...  English
# 6294  iebc kenya let s know upto tujue tuu na mapema...    sheng
# 6295  kenya petition website vote boatymcboatface mo...  English
# 6296                  williamsruto kura umeshindua wewe  Swahili
# 6297  mose m trying twist statement agents shallow a...  English
# 6298  karua ndio kigezo kwa kalonzo kujiunga na azim...    sheng
# 6299  rare picture hanging public private offices bu...  English
#
#       contains_emoji
# 0               True
# 1              False
# 2              False
# 3              False
# 4              False
# 5              False
# 6               True
# 7              False
# 8               True
# 9              False
# 10             False
# 11             False
# 12             False
# 13              True
# 14             False
# 6280            True
# 6281           False
# 6282           False
# 6283           False
# 6284           False
# 6285            True
# 6286           False
# 6287           False
# 6288           False
# 6289           False
# 6290           False
# 6291           False
# 6292           False
# 6293            True
# 6294           False
# 6295           False
# 6296           False
# 6297           False
# 6298           False
# 6299           False
