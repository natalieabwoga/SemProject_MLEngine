# %%
import pandas as pd
import numpy as np

# %%
political_dataset=pd.read_csv("../resources/kenya_political_tweets.csv")

# %% [markdown]
# ## 1. How many rows and columns are in the dataset?

# %%
political_dataset.shape
# Out:
# (11723, 16)

# %% [markdown]
# - The dataset has 11723 rows and 16 columns

# %%
political_dataset.head(5)
# Out:
#                     id    user_name user_location  \
# 0  1396091006030856192     Doomster  Utopia slums
# 1  1395981137764397056     Unruly 🗯    Morayfield
# 2  1395433210490798082       Khavin      Nairobi
# 3  1394739630898044931  Lecturer🇰🇪💥       Eldoret
# 4  1394561455471661057  Lecturer🇰🇪💥       Eldoret
#
#                                     user_description         user_created  \
# 0                    Alt-left, liberal, pronoun:them  2009-08-23 12:22:53
# 1  I don't know what you thought this was gonna b...  2011-04-20 19:35:54
# 2  CCTV installation and MAINTENANCE technician. ...  2020-02-11 04:52:44
# 3  President Kenyatta's critic.William Samoei Rut...  2020-01-23 19:10:51
# 4  President Kenyatta's critic.William Samoei Rut...  2020-01-23 19:10:51
#
#   user_followers user_friends user_favourites user_verified  \
# 0            309          907            8050         False
# 1           1053          523            5279         False
# ...

# %%
political_dataset.tail(5)
# Out:
#                         id                user_name     user_location  \
# 11718  1403061559727951875            Nation Africa             Kenya
# 11719  1403060195077545985  Joel Mulwa Njenga Jr 🇰🇪  Nyahururu, Kenya
# 11720  1403059933239721988                   Mutugi     Nairobi kenya
# 11721  1403059390568087556               TV47 Kenya    Nairobi, Kenya
# 11722  1403057818765254657                   Justin               NaN
#
#                                         user_description         user_created  \
# 11718  We are Nation. For customer care, 📨 support@na...  2009-03-23 10:15:38
# 11719  Laikipia general (Hustler)\npolitics and footb...  2015-08-20 11:31:10
# 11720                  A Clone Of Socrates And Einstein.  2021-03-29 13:40:13
# 11721  TV47 is a local, free-to-air television statio...  2015-02-13 08:17:41
# 11722     Optimist Educator| African History Researcher.  2019-07-03 05:07:34
#
#       user_followers user_friends user_favourites user_verified  \
# ...

# %%
political_dataset.describe()
# Out:
#            retweets     favorites
# count  11721.000000  11721.000000
# mean       7.571538     42.103234
# std       60.232891    317.674889
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      2.000000
# 75%        2.000000      8.000000
# max     3011.000000  16302.000000

# %% [markdown]
# ## 2. What datatypes are contained in the dataset?

# %%
political_dataset.dtypes
# Out:
# id                      str
# user_name               str
# user_location           str
# user_description        str
# user_created            str
# user_followers          str
# user_friends            str
# user_favourites         str
# user_verified        object
# date                    str
# text                    str
# hashtags                str
# source                  str
# retweets            float64
# favorites           float64
# is_retweet           object
# dtype: object

# %% [markdown]
# - The datatypes vary from strings, to objects to floats

# %% [markdown]
# ## 3. Is the Dataset Complete?

# %%
political_dataset.isna().sum()
# Out:
# id                      0
# user_name               0
# user_location        2484
# user_description      993
# user_created            1
# user_followers          1
# user_friends            1
# user_favourites         1
# user_verified           2
# date                    1
# text                    1
# hashtags            10549
# source                  1
# retweets                2
# favorites               2
# is_retweet              2
# dtype: int64

# %% [markdown]
# - The dataset is not complete as there are missing values in each column

# %% [markdown]
# ## 4. Slice out the first 15 rows and last 20 rows and merge them into a new dataframe titled `df_sample`. Display this new dataframe.

# %%
set_head=political_dataset.head(15)
set_tail=political_dataset.tail(20)

# %%
df_sample=pd.concat([set_head,set_tail])

# %%
df_sample.shape
# Out:
# (35, 16)

# %%
df_sample
# Out:
#                         id                    user_name     user_location  \
# 0      1396091006030856192                     Doomster      Utopia slums
# 1      1395981137764397056                     Unruly 🗯        Morayfield
# 2      1395433210490798082                       Khavin          Nairobi
# 3      1394739630898044931                  Lecturer🇰🇪💥           Eldoret
# 4      1394561455471661057                  Lecturer🇰🇪💥           Eldoret
# 5      1394334198417215493                  Lecturer🇰🇪💥           Eldoret
# 6      1394014196610781189                  Lecturer🇰🇪💥           Eldoret
# 7      1393619973524832257               G.G Peter Atom          Nairobi
# 8      1393618298684727298  Nyandarua County Government             Kenya
# 9      1393615018642579461          Suleiman H Sandhere        Somaliland
# 10     1393611039552458763                        Daudi            Kejani
# 11     1393610155632349190                   mike miraj           Niarobi
# ...
